# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Entrenamieto_ECI_2020.csv')
df.head()
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 3  16808  Americas  NW America                                   1
# 4  16805  Americas  NW America                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
df = df.iloc[:,np.r_[39:52]]
df.transpose()
# Out:
#                                               0                     1      \
# Planned_Delivery_Start_Date                5/1/2016             1/18/2016
# Planned_Delivery_End_Date                 6/30/2016             1/20/2016
# Month                                      2016 - 5              2016 - 1
# Delivery_Quarter                                 Q2                    Q1
# Delivery_Year                                  2016                  2016
# Actual_Delivery_Date                            NaT                   NaT
# TRF                                              10                     0
# Total_Amount_Currency                           EUR                   EUR
# Total_Amount                             5.2728e+06                 48230
# Total_Taxable_Amount_Currency                   EUR                   EUR
# Total_Taxable_Amount                     5.2728e+06                 48230
# Stage                                   Closed Lost            Closed Won
# ...

# %%
df.describe()
# Out:
#        Delivery_Year           TRF  Total_Amount  Total_Taxable_Amount
# count   16947.000000  16947.000000  1.688800e+04          1.694700e+04
# mean     2017.137428      2.338172  1.993659e+06          3.224117e+06
# std         0.829603     12.169339  1.848426e+07          2.030360e+07
# min      2016.000000      0.000000  0.000000e+00          0.000000e+00
# 25%      2016.000000      0.000000  2.677500e+04          8.546580e+04
# 50%      2017.000000      0.000000  1.072500e+05          3.760672e+05
# 75%      2018.000000      1.000000  4.603898e+05          1.037450e+06
# max      2020.000000    500.000000  1.320000e+09          1.356339e+09

# %%
df['Planned_Delivery_Start_Date'].value_counts()
# Out:
# 3/31/2016     381
# 2/29/2016     273
# 10/1/2018     211
# 4/2/2018      207
# 7/2/2018      169
#              ...
# 3/2/2018        1
# 10/21/2017      1
# 2/18/2017       1
# 5/27/2018       1
# 1/24/2016       1
# Name: Planned_Delivery_Start_Date, Length: 986, dtype: int64

# %%
df.Planned_Delivery_Start_Date=pd.to_datetime(df.Planned_Delivery_Start_Date)
df["Planned_Delivery_Start_Date_Year"]=df.Planned_Delivery_Start_Date.dt.year
df["Planned_Delivery_Start_Date_Year"].value_counts()
# Out:
# 2017    6318
# 2018    5830
# 2016    4371
# 2019     414
# 2020      14
# Name: Planned_Delivery_Start_Date_Year, dtype: int64

# %%
#Descarto el año 2020, ya que aporta un porcentaje mínimo que no es destacable a gran escala
planned_start_año = df.loc[ df['Planned_Delivery_Start_Date_Year'] != 2020]
planned_start_año["Planned_Delivery_Start_Date_Year"].value_counts()
# Out:
# 2017    6318
# 2018    5830
# 2016    4371
# 2019     414
# Name: Planned_Delivery_Start_Date_Year, dtype: int64

# %%
df["Planned_Delivery_Start_Date_Month"]=df.Planned_Delivery_Start_Date.dt.month
df["Planned_Delivery_Start_Date_Month"].value_counts()
# Out:
# 10    1676
# 3     1630
# 6     1563
# 7     1492
# 4     1484
# 5     1396
# 2     1388
# 1     1299
# 11    1291
# 9     1280
# 8     1271
# 12    1177
# Name: Planned_Delivery_Start_Date_Month, dtype: int64

# %%
df['Planned_Delivery_End_Date'].value_counts()
# Out:
# 3/31/2016    451
# 6/30/2017    322
# 2/29/2016    300
# 9/28/2018    262
# 6/29/2018    249
#             ...
# 6/18/2017      1
# 5/26/2018      1
# 1/6/2018       1
# 7/21/2018      1
# 8/2/2016       1
# Name: Planned_Delivery_End_Date, Length: 1017, dtype: int64

# %%
df.Planned_Delivery_End_Date=pd.to_datetime(df.Planned_Delivery_End_Date)
df["Planned_Delivery_End_Date_Year"]=df.Planned_Delivery_End_Date.dt.year
df["Planned_Delivery_End_Date_Year"].value_counts()
# Out:
# 2017.0    6284
# 2018.0    5828
# 2016.0    4301
# 2019.0     440
# 2020.0      17
# 2021.0       1
# 2208.0       1
# Name: Planned_Delivery_End_Date_Year, dtype: int64

# %%
#Descarto los años desde el 2020 en adelante, ya que solo abarcan el 0,11% del total.
planned_end_año = df.loc[ df['Planned_Delivery_End_Date_Year'] < 2020]
planned_end_año["Planned_Delivery_End_Date_Year"].value_counts()
# Out:
# 2017.0    6284
# 2018.0    5828
# 2016.0    4301
# 2019.0     440
# Name: Planned_Delivery_End_Date_Year, dtype: int64

# %%
df["Planned_Delivery_End_Date_Month"]=df.Planned_Delivery_End_Date.dt.month
df["Planned_Delivery_End_Date_Month"].value_counts()
# Out:
# 3.0     1914
# 6.0     1855
# 12.0    1795
# 9.0     1634
# 11.0    1321
# 5.0     1307
# 2.0     1295
# 10.0    1249
# 4.0     1232
# 8.0     1223
# 7.0     1141
# 1.0      906
# Name: Planned_Delivery_End_Date_Month, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# 2018 - 10    666
# 2017 - 6     643
# 2017 - 10    638
# 2016 - 3     628
# 2017 - 7     625
# 2017 - 5     586
# 2018 - 4     579
# 2017 - 12    574
# 2018 - 6     542
# 2018 - 7     536
# 2017 - 8     513
# 2018 - 2     498
# 2017 - 9     491
# 2017 - 3     487
# 2017 - 4     475
# 2018 - 3     467
# 2018 - 1     466
# 2018 - 5     461
# 2018 - 11    459
# 2017 - 11    450
# 2017 - 1     444
# 2016 - 2     440
# 2018 - 8     440
# 2018 - 9     406
# 2017 - 2     392
# 2016 - 4     383
# 2016 - 11    381
# 2016 - 9     380
# 2016 - 10    359
# 2016 - 6     352
# 2016 - 5     341
# 2016 - 8     313
# 2018 - 12    310
# 2016 - 7     306
# 2016 - 12    292
# 2016 - 1     196
# 2019 - 1     186
# 2019 - 2      58
# 2019 - 3      46
# 2019 - 4      44
# 2019 - 7      25
# 2019 - 6      25
# 2019 - 10     13
# 2019 - 5       8
# 2020 - 1       7
# 2019 - 8       5
# 2020 - 4       3
# 2020 - 3       2
# 2019 - 9       2
# 2019 - 11      1
# 2020 - 9       1
# 2020 - 6       1
# ...

# %%
df['Delivery_Quarter'].value_counts()
# Out:
# Q2    4443
# Q1    4317
# Q4    4144
# Q3    4043
# Name: Delivery_Quarter, dtype: int64

# %%
df['Delivery_Year'].value_counts()
# Out:
# 2017    6318
# 2018    5830
# 2016    4371
# 2019     414
# 2020      14
# Name: Delivery_Year, dtype: int64

# %%
#Como sus valores son exactamente iguales al año de la columna Planned_Delivery_Start_Date, se descarta
df = df.drop(columns='Delivery_Year')

# %%
df['Actual_Delivery_Date'].value_counts()
# Out:
# NaT    16947
# Name: Actual_Delivery_Date, dtype: int64

# %%
#Como el valor no varía y no aporta información importante, se descarta la columna
df = df.drop(columns='Actual_Delivery_Date')

# %%
df['TRF'].value_counts()
# Out:
# 0      11971
# 1       2192
# 2        627
# 3        354
# 5        297
#        ...
# 51         1
# 167        1
# 163        1
# 195        1
# 165        1
# Name: TRF, Length: 101, dtype: int64

# %%
df['Total_Amount_Currency'].value_counts()
# Out:
# USD    7361
# JPY    4522
# EUR    4503
# AUD     556
# GBP       5
# Name: Total_Amount_Currency, dtype: int64

# %%
df['Total_Amount'].value_counts()
# Out:
# 6200.0        513
# 4400.0        461
# 18000.0       353
# 140000.0      272
# 1600.0        204
#              ...
# 193600.0        1
# 4972.8          1
# 8001840.0       1
# 12333750.0      1
# 11960.0         1
# Name: Total_Amount, Length: 8872, dtype: int64

# %%
df['Total_Taxable_Amount_Currency'].value_counts()
# Out:
# USD    7347
# JPY    4525
# EUR    4518
# AUD     553
# GBP       4
# Name: Total_Taxable_Amount_Currency, dtype: int64

# %%
df['Total_Taxable_Amount'].value_counts()
# Out:
# 0.0           997
# 588325.0       72
# 109620.0       68
# 488700.0       66
# 413700.0       60
#              ...
# 18698803.2      1
# 27800800.0      1
# 215.6           1
# 12852000.0      1
# 121837.5        1
# Name: Total_Taxable_Amount, Length: 7096, dtype: int64

# %%
df['Prod_Category_A'].value_counts()
# Out:
# Prod_Category_A_None    16947
# Name: Prod_Category_A, dtype: int64

# %%
#Como en el caso anterior, al no aportar nada de información destacable, se descarta
df = df.drop(columns='Prod_Category_A')

# %%
start_date = df[["Planned_Delivery_Start_Date","Stage"]].groupby(["Planned_Delivery_Start_Date","Stage"]).agg({"Stage":"count"})
start_date.head(1)
# Out:
#                                          Stage
# Planned_Delivery_Start_Date Stage
# 2016-01-01                  Closed Lost     12

# %%
start_date.columns={"Opened_Amount"}
start_date.reset_index(inplace=True)
start_date.head(1)
# Out:
#   Planned_Delivery_Start_Date        Stage  Opened_Amount
# 0                  2016-01-01  Closed Lost             12

# %%
aprob_fecha_inicial = start_date.loc[start_date.Stage.str.contains("Closed Won")].sort_values("Opened_Amount",ascending=False)
aprob_fecha_inicial = aprob_fecha_inicial[["Planned_Delivery_Start_Date","Opened_Amount"]]
aprob_fecha_inicial.rename(columns={"Opened_Amount":"Opened_Amount_Won"},inplace=True)
aprob_fecha_inicial.head()
# Out:
#      Planned_Delivery_Start_Date  Opened_Amount_Won
# 1121                  2018-04-02                 97
# 572                   2017-03-27                 85
# 1037                  2018-02-01                 82
# 1078                  2018-03-01                 71
# 858                   2017-10-02                 68

# %%
df['Stage'].value_counts(normalize=True)
# Out:
# Closed Won       0.562518
# Closed Lost      0.433705
# Proposal         0.002065
# Negotiation      0.001062
# Qualification    0.000649
# Name: Stage, dtype: float64

# %%
sns.palplot(sns.color_palette('Paired', 10))

# %%
palette = sns.color_palette('Paired', 10)
red = palette[5]
green = palette[3]
blue = palette[1]

# %%
palette_dic ={'Closed Lost':red,'Closed Won':green, 'Other':blue}

# %%
g = df.loc[:,['Total_Taxable_Amount_Currency', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Total_Taxable_Amount_Currency')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Total_Taxable_Amount_Currency')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Total_Taxable_Amount_Currency'], hue=g['Stage'], order=g.dropna(subset=['Total_Taxable_Amount_Currency'])\
              .drop_duplicates('Total_Taxable_Amount_Currency').iloc[:15]['Total_Taxable_Amount_Currency'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Total_Taxable_Amount_Currency respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Tipo de moneda', fontsize=16)
# Out:
# Text(0, 0.5, 'Tipo de moneda')

# %%
g = df.loc[:,['Total_Amount_Currency', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Total_Amount_Currency')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Total_Amount_Currency')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Total_Amount_Currency'], hue=g['Stage'], order=g.dropna(subset=['Total_Amount_Currency'])\
              .drop_duplicates('Total_Amount_Currency').iloc[:15]['Total_Amount_Currency'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Total_Amount_Currency respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Tipo de moneda', fontsize=16)
# Out:
# Text(0, 0.5, 'Tipo de moneda')

# %%
df.loc[ df['Total_Taxable_Amount_Currency'] == df['Total_Amount_Currency'] ]
# Out:
#       Planned_Delivery_Start_Date Planned_Delivery_End_Date     Month  \
# 0                      2016-05-01                2016-06-30  2016 - 5
# 1                      2016-01-18                2016-01-20  2016 - 1
# 2                      2016-01-25                2016-01-25  2016 - 1
# 3                      2018-02-01                2018-03-31  2018 - 2
# 4                      2018-02-01                2018-02-28  2018 - 2
# ...                           ...                       ...       ...
# 16942                  2016-03-21                2016-03-25  2016 - 3
# 16943                  2016-04-04                2016-04-08  2016 - 4
# 16944                  2016-03-28                2016-03-31  2016 - 3
# 16945                  2016-04-25                2016-04-29  2016 - 4
# 16946                  2016-07-01                2016-08-31  2016 - 7
#
#       Delivery_Quarter  TRF Total_Amount_Currency  Total_Amount  \
# ...

# %%
#Como la diferencia entre las columnas Total_Taxable_Amount_Currency y Total_Amount_Currency es mínima,
#habiendo solamente un 0,19% de filas distintas, decido quedarme con Total_Taxable_Amount_Currency y descartar
#la otra columna.

df = df.drop(columns='Total_Amount_Currency')

# %%
#Verifico lo mismo para Total_Taxable_Amount y Total_Amount

df.loc[ df['Total_Taxable_Amount'] == df['Total_Amount'] ]
# Out:
#       Planned_Delivery_Start_Date Planned_Delivery_End_Date     Month  \
# 0                      2016-05-01                2016-06-30  2016 - 5
# 1                      2016-01-18                2016-01-20  2016 - 1
# 2                      2016-01-25                2016-01-25  2016 - 1
# 3                      2018-02-01                2018-03-31  2018 - 2
# 4                      2018-02-01                2018-02-28  2018 - 2
# ...                           ...                       ...       ...
# 16930                  2016-04-04                2016-06-30  2016 - 4
# 16931                  2016-02-22                2016-03-11  2016 - 2
# 16932                  2016-02-22                2016-03-31  2016 - 2
# 16938                  2016-08-15                2016-09-30  2016 - 8
# 16939                  2016-04-01                2016-04-21  2016 - 4
#
#       Delivery_Quarter  TRF  Total_Amount Total_Taxable_Amount_Currency  \
# ...

# %%
#Como la diferencia es considerable, siendo nada más el 37,6% con valores iguales y 62,4% diferentes, necesito
#quedarme con ambas columnas.

# %%
df.head()
# Out:
#   Planned_Delivery_Start_Date Planned_Delivery_End_Date     Month  \
# 0                  2016-05-01                2016-06-30  2016 - 5
# 1                  2016-01-18                2016-01-20  2016 - 1
# 2                  2016-01-25                2016-01-25  2016 - 1
# 3                  2018-02-01                2018-03-31  2018 - 2
# 4                  2018-02-01                2018-02-28  2018 - 2
#
#   Delivery_Quarter  TRF  Total_Amount Total_Taxable_Amount_Currency  \
# 0               Q2   10     5272800.0                           EUR
# 1               Q1    0       48230.0                           EUR
# 2               Q1    0       83865.6                           USD
# 3               Q1   14     7421881.5                           USD
# 4               Q1   25    13357192.5                           USD
#
#    Total_Taxable_Amount        Stage  Planned_Delivery_Start_Date_Year  \
# 0             5272800.0  Closed Lost                              2016
# ...

# %%
g = df.loc[:,['Delivery_Quarter', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Delivery_Quarter')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Delivery_Quarter')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Delivery_Quarter'], hue=g['Stage'], order=g.dropna(subset=['Delivery_Quarter'])\
              .drop_duplicates('Delivery_Quarter').iloc[:15]['Delivery_Quarter'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Delivery_Quarter respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Cuatrimestre', fontsize=16)
# Out:
# Text(0, 0.5, 'Cuatrimestre')

# %%
g = df.groupby(["TRF","Stage"]).agg({"Stage":"count"}).rename(columns={"Stage":"cant_stage"}).reset_index().sort_values("cant_stage",ascending=False).head(15)#.value_counts()#.head(10)
g
# Out:
#     TRF        Stage  cant_stage
# 1     0   Closed Won        8236
# 0     0  Closed Lost        3706
# 5     1  Closed Lost        1311
# 6     1   Closed Won         866
# 10    2  Closed Lost         454
# 14    3  Closed Lost         277
# 20    5  Closed Lost         256
# 34   10  Closed Lost         170
# 11    2   Closed Won         167
# 17    4  Closed Lost         162
# 24    6  Closed Lost         107
# 26    7  Closed Lost          89
# 57   20  Closed Lost          78
# 15    3   Closed Won          76
# 36   11  Closed Lost          56

# %%
sns.set(font_scale=2) 
g_plot=sns.catplot(x="TRF",y="cant_stage",col="Stage",\
    data=g,hue="Stage",kind="bar",height=6, aspect=2)
plt.show()

# %%
g = df.groupby(['Month','Stage']).agg({"Stage":"count"}).rename(columns={"Stage":"cant_stage"}).reset_index().sort_values("cant_stage",ascending=False).head(15)
g_plot=sns.catplot(x="cant_stage",y="Month",col="Stage",\
    data=g,hue="Stage",kind="bar",height=8, aspect=1)
plt.show()

# %%
g = planned_start_año.loc[:,['Planned_Delivery_Start_Date_Year', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Planned_Delivery_Start_Date_Year')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Planned_Delivery_Start_Date_Year')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Planned_Delivery_Start_Date_Year'], hue=g['Stage'], order=g.dropna(subset=['Planned_Delivery_Start_Date_Year'])\
              .drop_duplicates('Planned_Delivery_Start_Date_Year').iloc[:15]['Planned_Delivery_Start_Date_Year'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Planned_Delivery_Start_Date por año respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Año', fontsize=16)
# Out:
# Text(0, 0.5, 'Año')

# %%
g = df.loc[:,['Planned_Delivery_Start_Date_Month', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Planned_Delivery_Start_Date_Month')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Planned_Delivery_Start_Date_Month')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,12))
sns.countplot(y=g['Planned_Delivery_Start_Date_Month'], hue=g['Stage'], order=g.dropna(subset=['Planned_Delivery_Start_Date_Month'])\
              .drop_duplicates('Planned_Delivery_Start_Date_Month').iloc[:15]['Planned_Delivery_Start_Date_Month'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Planned_Delivery_Start_Date por mes respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Año', fontsize=16)
# Out:
# Text(0, 0.5, 'Año')

# %%
g = planned_end_año.loc[:,['Planned_Delivery_End_Date_Year', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Planned_Delivery_End_Date_Year')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Planned_Delivery_End_Date_Year')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Planned_Delivery_End_Date_Year'], hue=g['Stage'], order=g.dropna(subset=['Planned_Delivery_End_Date_Year'])\
              .drop_duplicates('Planned_Delivery_End_Date_Year').iloc[:15]['Planned_Delivery_End_Date_Year'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Planned_Delivery_End_Date por año respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Año', fontsize=16)
# Out:
# Text(0, 0.5, 'Año')

# %%
g = df.loc[:,['Planned_Delivery_End_Date_Month', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_fecha'] = g.groupby('Planned_Delivery_End_Date_Month')['Stage'].transform('sum')
g['Lost_por_fecha'] = abs(g.groupby('Planned_Delivery_End_Date_Month')['Stage'].transform('count') - g['Won_por_fecha'])
g['Stage_diff'] = abs(g['Won_por_fecha'] - g['Lost_por_fecha'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,12))
sns.countplot(y=g['Planned_Delivery_End_Date_Month'], hue=g['Stage'], order=g.dropna(subset=['Planned_Delivery_End_Date_Month'])\
              .drop_duplicates('Planned_Delivery_End_Date_Month').iloc[:15]['Planned_Delivery_End_Date_Month'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Planned_Delivery_End_Date por mes respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Año', fontsize=16)
# Out:
# Text(0, 0.5, 'Año')

# %%
df
# Out:
#       Planned_Delivery_Start_Date Planned_Delivery_End_Date     Month  \
# 0                      2016-05-01                2016-06-30  2016 - 5
# 1                      2016-01-18                2016-01-20  2016 - 1
# 2                      2016-01-25                2016-01-25  2016 - 1
# 3                      2018-02-01                2018-03-31  2018 - 2
# 4                      2018-02-01                2018-02-28  2018 - 2
# ...                           ...                       ...       ...
# 16942                  2016-03-21                2016-03-25  2016 - 3
# 16943                  2016-04-04                2016-04-08  2016 - 4
# 16944                  2016-03-28                2016-03-31  2016 - 3
# 16945                  2016-04-25                2016-04-29  2016 - 4
# 16946                  2016-07-01                2016-08-31  2016 - 7
#
#       Delivery_Quarter  TRF  Total_Amount Total_Taxable_Amount_Currency  \
# ...

# %%
#Cambio Total_Taxable_Amount a USD
df.loc[df.Total_Taxable_Amount_Currency == "EUR", "Total_Taxable_Amount"] *= 1.19
df.loc[df.Total_Taxable_Amount_Currency == "JPY", "Total_Taxable_Amount"] *= 0.0096
df.loc[df.Total_Taxable_Amount_Currency == "AUD", "Total_Taxable_Amount"] *= 0.73
df.loc[df.Total_Taxable_Amount_Currency == "GBP", "Total_Taxable_Amount"] *= 1.32

#Renombro la columna ya que ahora todos se muestran en USD
df = df.rename(columns={'Total_Taxable_Amount':'Total_Taxable_Amount_USD'})

# %%
#Cambio Total_Amount a USD
df.loc[df.Total_Taxable_Amount_Currency == "EUR", "Total_Amount"] *= 1.19
df.loc[df.Total_Taxable_Amount_Currency == "JPY", "Total_Amount"] *= 0.0096
df.loc[df.Total_Taxable_Amount_Currency == "AUD", "Total_Amount"] *= 0.73
df.loc[df.Total_Taxable_Amount_Currency == "GBP", "Total_Amount"] *= 1.32

#Renombro la columna ya que ahora todos se muestran en USD
df = df.rename(columns={'Total_Amount':'Total_Amount_USD'})

# %%
g = df.groupby(['Total_Amount_USD','Stage']).agg({"Stage":"count"}).rename(columns={"Stage":"cant_stage"}).reset_index().sort_values("cant_stage",ascending=False).head(15)
sns.relplot(x="cant_stage", y="Total_Amount_USD", hue="Stage", data=g, height=8, aspect=2);

# %%
g = df.loc[:,['Total_Amount_USD', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_precio'] = g.groupby('Total_Amount_USD')['Stage'].transform('sum')
g['Lost_por_precio'] = abs(g.groupby('Total_Amount_USD')['Stage'].transform('count') - g['Won_por_precio'])
g['Stage_diff'] = abs(g['Won_por_precio'] - g['Lost_por_precio'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,12))
sns.countplot(y=g['Total_Amount_USD'], hue=g['Stage'], order=g.dropna(subset=['Total_Amount_USD'])\
              .drop_duplicates('Total_Amount_USD').iloc[:15]['Total_Amount_USD'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Total_Amount_USD respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Monto Total en USD', fontsize=16)
# Out:
# Text(0, 0.5, 'Monto Total en USD')

# %%
g = df.groupby(['Total_Taxable_Amount_USD','Stage']).agg({"Stage":"count"}).rename(columns={"Stage":"cant_stage"}).reset_index().sort_values("cant_stage",ascending=False).head(15)
sns.relplot(x="cant_stage", y="Total_Taxable_Amount_USD", hue="Stage", data=g, height=6, aspect=1);

# %%
g = df.loc[:,['Total_Taxable_Amount_USD', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_precio'] = g.groupby('Total_Taxable_Amount_USD')['Stage'].transform('sum')
g['Lost_por_precio'] = abs(g.groupby('Total_Taxable_Amount_USD')['Stage'].transform('count') - g['Won_por_precio'])
g['Stage_diff'] = abs(g['Won_por_precio'] - g['Lost_por_precio'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,12))
sns.countplot(y=g['Total_Taxable_Amount_USD'], hue=g['Stage'], order=g.dropna(subset=['Total_Taxable_Amount_USD'])\
              .drop_duplicates('Total_Taxable_Amount_USD').iloc[:15]['Total_Taxable_Amount_USD'].values, \
             palette=palette_dic)

plt.title('Cantidad de registros en la columna Total_Taxable_Amount_USD respecto a Stage', fontsize=20);
plt.xlabel('Cantidad de registros', fontsize=16);
plt.ylabel('Monto Total en USD', fontsize=16)
# Out:
# Text(0, 0.5, 'Monto Total en USD')
