# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Entrenamieto_ECI_2020.csv')
df.head()
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 3  16808  Americas  NW America                                   1
# 4  16805  Americas  NW America                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
df.transpose()
# Out:
#                                                      0      \
# ID                                                   27761
# Region                                                EMEA
# Territory                                             None
# Pricing, Delivery_Terms_Quote_Appr                       1
# Pricing, Delivery_Terms_Approved                         1
# Bureaucratic_Code_0_Approval                             1
# Bureaucratic_Code_0_Approved                             1
# Submitted_for_Approval                                   0
# Bureaucratic_Code                      Bureaucratic_Code_4
# Account_Created_Date                             6/16/2015
# Source                                                None
# Billing_Country                                Netherlands
# Account_Name                              Account_Name_619
# Opportunity_Name                    Opportunity_Name_12598
# Opportunity_ID                                           0
# ...

# %%
df[df['Product_Name'] == 'Product_Name_240'][['Opportunity_Created_Date','Last_Modified_Date','Product_Name', 'Price', 'Currency', 'ASP', 'ASP_Currency', 'ASP_(converted)', 'Stage']]
# Out:
#       Opportunity_Created_Date Last_Modified_Date      Product_Name  Price  \
# 8140                  6/9/2017          3/14/2018  Product_Name_240   None
# 11428               12/20/2017          8/16/2018  Product_Name_240   None
# 11863                 4/9/2018           5/3/2018  Product_Name_240   None
# 12726                2/13/2018          3/15/2018  Product_Name_240   None
# 12781                2/15/2018          9/26/2018  Product_Name_240   None
# 13135                4/18/2018          9/26/2018  Product_Name_240   None
# 13137                4/18/2018          7/30/2018  Product_Name_240   None
# 13163                4/20/2018          9/10/2018  Product_Name_240   0.33
# 14070                6/23/2018          12/7/2018  Product_Name_240   None
# 14147                6/29/2018          8/17/2018  Product_Name_240  Other
# 14594                7/31/2018          8/10/2018  Product_Name_240   None
# ...

# %%
#Me quedo con las columnas a analizar mas la de Stage
df = df.iloc[:,np.r_[26:39, 50]]
df.transpose()
# Out:
#                                       0                  1      \
# Product_Category_B                     None               None
# Price                                  None               None
# Currency                               None               None
# Last_Activity                           NaT                NaT
# Quote_Expiry_Date                 1/30/2016          1/20/2016
# Last_Modified_Date                6/13/2016          1/15/2016
# Last_Modified_By             Person_Name_18     Person_Name_20
# Product_Family            Product_Family_77  Product_Family_77
# Product_Name                Product_Name_99   Product_Name_100
# ASP_Currency                            EUR                EUR
# ASP                                    0.52               0.53
# ASP_(converted)_Currency                USD                USD
# ASP_(converted)                     0.58817            0.59948
# Stage                           Closed Lost         Closed Won
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Product_Category_B        16947 non-null  object
#  1   Price                     16947 non-null  object
#  2   Currency                  16947 non-null  object
#  3   Last_Activity             16947 non-null  object
#  4   Quote_Expiry_Date         16947 non-null  object
#  5   Last_Modified_Date        16947 non-null  object
#  6   Last_Modified_By          16947 non-null  object
#  7   Product_Family            16947 non-null  object
#  8   Product_Name              16947 non-null  object
#  9   ASP_Currency              16947 non-null  object
#  10  ASP                       13738 non-null  float64
#  11  ASP_(converted)_Currency  16947 non-null  object
#  12  ASP_(converted)           13738 non-null  float64
# ...

# %%
df['Product_Category_B'].value_counts()
# Out:
# None                     15928
# Other                      523
# Product_Category_B_2        59
# Product_Category_B_12       51
# Product_Category_B_7        47
# Product_Category_B_4        37
# Product_Category_B_5        36
# Product_Category_B_17       27
# Product_Category_B_1        24
# Product_Category_B_3        23
# Product_Category_B_8        23
# Product_Category_B_19       22
# Product_Category_B_11       21
# Product_Category_B_13       18
# Product_Category_B_16       17
# Product_Category_B_9        17
# Product_Category_B_24       16
# Product_Category_B_6         9
# Product_Category_B_20        9
# Product_Category_B_15        8
# Product_Category_B_21        8
# Product_Category_B_23        5
# Product_Category_B_14        4
# Product_Category_B_26        4
# Product_Category_B_0         3
# Product_Category_B_10        3
# Product_Category_B_27        3
# Product_Category_B_22        2
# Name: Product_Category_B, dtype: int64

# %%
df.describe()
# Out:
#                 ASP  ASP_(converted)
# count  13738.000000     13738.000000
# mean       7.012128         0.432554
# std       18.858359         0.758659
# min        0.000000         0.000000
# 25%        0.360000         0.373260
# 50%        0.400000         0.412850
# 75%        0.505000         0.476490
# max       80.000000        67.000000

# %%
df['ASP_Currency'].value_counts()
# Out:
# USD    7361
# JPY    4522
# EUR    4503
# AUD     556
# GBP       5
# Name: ASP_Currency, dtype: int64

# %%
df.head()
# Out:
#       Product_Category_B Price Currency Last_Activity Quote_Expiry_Date  \
# 0                   None  None     None           NaT         1/30/2016
# 1                   None  None     None           NaT         1/20/2016
# 2                   None  None     None           NaT         9/30/2016
# 3  Product_Category_B_16  0.42      USD           NaT               NaT
# 4  Product_Category_B_16  0.42      USD           NaT          6/2/2017
#
#   Last_Modified_Date Last_Modified_By      Product_Family      Product_Name  \
# 0          6/13/2016   Person_Name_18   Product_Family_77   Product_Name_99
# 1          1/15/2016   Person_Name_20   Product_Family_77  Product_Name_100
# 2          9/29/2016    Person_Name_8   Product_Family_81   Product_Name_91
# 3          3/27/2018    Person_Name_8  Product_Family_209  Product_Name_432
# 4          3/27/2018    Person_Name_8  Product_Family_209  Product_Name_432
#
#   ASP_Currency   ASP ASP_(converted)_Currency  ASP_(converted)        Stage
# ...

# %%
df['Price'].value_counts().head(10)
# Out:
# None     15982
# Other      609
# 0.24        27
# 0.41        22
# 0.28        20
# 0.27        18
# 0.29        17
# 0.32        15
# 0.35        14
# 0.38        14
# Name: Price, dtype: int64

# %%
df['Last_Activity'].value_counts()
# Out:
# NaT    16947
# Name: Last_Activity, dtype: int64

# %%
#La columna Last_Activity tiene el mismo valor en todas sus filas, la elimino
df = df.drop(columns='Last_Activity')

# %%
df.head()
# Out:
#       Product_Category_B Price Currency Quote_Expiry_Date Last_Modified_Date  \
# 0                   None  None     None         1/30/2016          6/13/2016
# 1                   None  None     None         1/20/2016          1/15/2016
# 2                   None  None     None         9/30/2016          9/29/2016
# 3  Product_Category_B_16  0.42      USD               NaT          3/27/2018
# 4  Product_Category_B_16  0.42      USD          6/2/2017          3/27/2018
#
#   Last_Modified_By      Product_Family      Product_Name ASP_Currency   ASP  \
# 0   Person_Name_18   Product_Family_77   Product_Name_99          EUR  0.52
# 1   Person_Name_20   Product_Family_77  Product_Name_100          EUR  0.53
# 2    Person_Name_8   Product_Family_81   Product_Name_91          USD  0.48
# 3    Person_Name_8  Product_Family_209  Product_Name_432          USD  0.53
# 4    Person_Name_8  Product_Family_209  Product_Name_432          USD  0.53
#
# ...

# %%
df['Currency'].value_counts()
# Out:
# None    16052
# EUR       475
# USD       420
# Name: Currency, dtype: int64

# %%
df['Quote_Expiry_Date'].value_counts()
# Out:
# NaT           4625
# 6/30/2017      436
# 3/31/2017      363
# 9/30/2017      225
# 12/31/2016     200
#               ...
# 8/14/2015        1
# 12/3/2018        1
# 10/23/2016       1
# 1/11/2019        1
# 10/9/2018        1
# Name: Quote_Expiry_Date, Length: 1003, dtype: int64

# %%
df['Last_Modified_Date'].value_counts()
# Out:
# 2/8/2018     5821
# 12/4/2016    2673
# 9/6/2018      257
# 9/26/2018     206
# 6/9/2018      187
#              ...
# 8/8/2017        1
# 3/21/2017       1
# 7/18/2016       1
# 8/18/2017       1
# 9/30/2018       1
# Name: Last_Modified_Date, Length: 650, dtype: int64

# %%
df['Last_Modified_Date']
# Out:
# 0        6/13/2016
# 1        1/15/2016
# 2        9/29/2016
# 3        3/27/2018
# 4        3/27/2018
#            ...
# 16942    1/19/2016
# 16943    1/19/2016
# 16944    1/19/2016
# 16945    1/22/2016
# 16946    9/28/2016
# Name: Last_Modified_Date, Length: 16947, dtype: object

# %%
df['Last_Modified_Date'] = pd.to_datetime(df['Last_Modified_Date'], infer_datetime_format=True)
df['Last_Modified_Date']
# Out:
# 0       2016-06-13
# 1       2016-01-15
# 2       2016-09-29
# 3       2018-03-27
# 4       2018-03-27
#            ...
# 16942   2016-01-19
# 16943   2016-01-19
# 16944   2016-01-19
# 16945   2016-01-22
# 16946   2016-09-28
# Name: Last_Modified_Date, Length: 16947, dtype: datetime64[ns]

# %%
df['Last_Modified_By'].value_counts().head(10)
# Out:
# Person_Name_47    8515
# Person_Name_50    1210
# Person_Name_43     587
# Person_Name_13     578
# Person_Name_8      511
# Person_Name_18     438
# Person_Name_33     429
# Person_Name_19     395
# Person_Name_3      395
# Person_Name_4      315
# Name: Last_Modified_By, dtype: int64

# %%
df['Product_Family'].value_counts()
# Out:
# Product_Family_77     1345
# Product_Family_133    1249
# Product_Family_132     763
# Product_Family_212     636
# Product_Family_100     619
#                       ...
# Product_Family_48        1
# Product_Family_166       1
# Product_Family_236       1
# Product_Family_51        1
# Product_Family_66        1
# Name: Product_Family, Length: 227, dtype: int64

# %%
df['Product_Name'].value_counts()
# Out:
# Product_Name_100    976
# Product_Name_226    836
# Product_Name_231    579
# Product_Name_491    524
# Product_Name_4      474
#                    ...
# Product_Name_126      1
# Product_Name_426      1
# Product_Name_507      1
# Product_Name_462      1
# Product_Name_510      1
# Name: Product_Name, Length: 456, dtype: int64

# %%
df['ASP'].value_counts()
# Out:
# 0.38000    801
# 0.40000    712
# 0.36000    564
# 0.42000    510
# 0.39000    465
#           ...
# 0.34730      1
# 0.27400      1
# 0.25300      1
# 0.45789      1
# 0.24400      1
# Name: ASP, Length: 301, dtype: int64

# %%
df.groupby('Product_Name')['ASP'].mean()
# Out:
# Product_Name
# Product_Name_0       0.000000
# Product_Name_1       0.000000
# Product_Name_10      0.000000
# Product_Name_100    36.373088
# Product_Name_101     0.277500
#                       ...
# Product_Name_95      0.292500
# Product_Name_96      7.026517
# Product_Name_97      6.540094
# Product_Name_98      2.048068
# Product_Name_99      1.636016
# Name: ASP, Length: 456, dtype: float64

# %%
df[df['Product_Name'] == 'Product_Name_0']['ASP'].value_counts()
# Out:
# 0.0    9
# Name: ASP, dtype: int64

# %%
df['ASP_(converted)_Currency'].value_counts()
# Out:
# USD    16947
# Name: ASP_(converted)_Currency, dtype: int64

# %%
#Todas los ASP estan convertidos a USD, elimino la columna 
#y aclaro que los ASP convertidos estan en USD
df = df.drop(columns='ASP_(converted)_Currency').rename(columns={'ASP_(converted)':'ASP_USD'})
df.head()
# Out:
#       Product_Category_B Price Currency Quote_Expiry_Date Last_Modified_Date  \
# 0                   None  None     None         1/30/2016         2016-06-13
# 1                   None  None     None         1/20/2016         2016-01-15
# 2                   None  None     None         9/30/2016         2016-09-29
# 3  Product_Category_B_16  0.42      USD               NaT         2018-03-27
# 4  Product_Category_B_16  0.42      USD          6/2/2017         2018-03-27
#
#   Last_Modified_By      Product_Family      Product_Name ASP_Currency   ASP  \
# 0   Person_Name_18   Product_Family_77   Product_Name_99          EUR  0.52
# 1   Person_Name_20   Product_Family_77  Product_Name_100          EUR  0.53
# 2    Person_Name_8   Product_Family_81   Product_Name_91          USD  0.48
# 3    Person_Name_8  Product_Family_209  Product_Name_432          USD  0.53
# 4    Person_Name_8  Product_Family_209  Product_Name_432          USD  0.53
#
#    ASP_USD        Stage
# ...

# %%
df['ASP_USD'].value_counts()
# Out:
# 0.38000    570
# 0.40000    497
# 0.36000    326
# 0.39000    325
# 0.00000    300
#           ...
# 0.32365      1
# 0.67868      1
# 0.43820      1
# 0.47300      1
# 0.30567      1
# Name: ASP_USD, Length: 441, dtype: int64

# %%
df['Product_Family'].value_counts()
# Out:
# Product_Family_77     1345
# Product_Family_133    1249
# Product_Family_132     763
# Product_Family_212     636
# Product_Family_100     619
#                       ...
# Product_Family_48        1
# Product_Family_166       1
# Product_Family_236       1
# Product_Family_51        1
# Product_Family_66        1
# Name: Product_Family, Length: 227, dtype: int64

# %%
df['Stage'].value_counts(normalize=True)
# Out:
# Closed Won       0.562518
# Closed Lost      0.433705
# Proposal         0.002065
# Negotiation      0.001062
# Qualification    0.000649
# Name: Stage, dtype: float64

# %%
sns.palplot(sns.color_palette('Paired', 10))

# %%
palette = sns.color_palette('Paired', 10)
red = palette[5]
green = palette[3]
blue = palette[1]

# %%
palette_dic ={'Closed Lost':red,'Closed Won':green, 'Other':blue}

# %%
#El 99% de las oportunidades estan en Closed Won y Closed Lost, las grafico

values = ['Closed Won', 'Closed Lost']
g = df.copy()
g['Stage'] = g['Stage'].replace(['Proposal', 'Negotiation', 'Qualification'], 'Other')
g['Porcentaje'] = g['Stage'].map(g['Stage'].value_counts(normalize=True)).mul(100)
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Stage', y='Porcentaje', data = g, palette=palette_dic)

for p in ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x()
    txt_y = p.get_height()
    ax.text(txt_x,txt_y,txt)

plt.title('Distribución de la variable Stage', size=14, y=1.02, fontweight ='bold')

#plt.savefig('Visualizacion1.png', bbox_inches='tight')

# %%
#O grafico solo para los datos con Closed Lost y Closed Won

values = ['Closed Won', 'Closed Lost']
g = df.loc[df['Stage'].isin(values)].copy()
g['Porcentaje'] = g['Stage'].map(g['Stage'].value_counts(normalize=True)).mul(100)
plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Stage', y='Porcentaje', data = g, palette=palette_dic)

for p in ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    ax.text(txt_x,txt_y,txt)

plt.title('Distribución de la variable Stage', size=14, y=1.02, fontweight ='bold')

#plt.savefig('Visualizacion2.png', bbox_inches='tight')

# %%
g = df.loc[:,['Product_Family', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_family'] = g.groupby('Product_Family')['Stage'].transform('sum')
g['Lost_por_family'] = abs(g.groupby('Product_Family')['Stage'].transform('count') - g['Won_por_family'])
g['Stage_diff'] = abs(g['Won_por_family'] - g['Lost_por_family'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Product_Family'], hue=g['Stage'], order=g.dropna(subset=['Product_Family'])\
              .drop_duplicates('Product_Family').iloc[:15]['Product_Family'].values, \
             palette=palette_dic)

plt.title('Las 15 familias de productos con mayor diferencia entre exito y fracaso', size=14, y=1.02,\
             fontweight ='bold')
plt.ylabel('Familia de producto')
plt.xlabel('Cantidad de oportunidades')
plt.legend(title='Resultado de la oportunidad')

#plt.savefig('Visualizacion3.png', bbox_inches='tight')

# %%
g = df.loc[:,['Product_Name', 'Stage']]
g['Stage'] = g['Stage'].map({'Closed Won':1,'Closed Lost':0})
g['Won_por_family'] = g.groupby('Product_Name')['Stage'].transform('sum')
g['Lost_por_family'] = abs(g.groupby('Product_Name')['Stage'].transform('count') - g['Won_por_family'])
g['Stage_diff'] = abs(g['Won_por_family'] - g['Lost_por_family'])
g['Stage'] = g['Stage'].map({1:'Exito',0:'Fracaso'})
g = g.sort_values('Stage_diff', ascending=False)

palette_dic ={'Fracaso':red,'Exito':green}
plt.figure(figsize=(12,10))
sns.countplot(y=g['Product_Name'], hue=g['Stage'], order=g.dropna(subset=['Product_Name'])\
              .drop_duplicates('Product_Name').iloc[:15]['Product_Name'].values, \
             palette=palette_dic)

plt.title('Los 15 productos con mayor diferencia entre exito y fracaso', size=14, y=1.02,\
             fontweight ='bold')
plt.ylabel('Nombre de producto')
plt.xlabel('Cantidad de oportunidades')
plt.legend(title='Resultado de la oportunidad')

#plt.savefig('Visualizacion4.png', bbox_inches='tight')

# %% [markdown]
# Analisis para la variable 'ASP_USD'

# %%
nulos_usd = df['ASP_USD'].isna().sum()
nulos_usd
# Out:
# 3209

# %%
no_nulos_usd = df['ASP_USD'].count()
no_nulos_usd
# Out:
# 13738

# %%
total_usd = len(df['ASP_USD'])
total_usd
# Out:
# 16947

# %%
#No contiene datos menores a 0
df['ASP_USD'].nsmallest(10)
# Out:
# 110    0.0
# 196    0.0
# 197    0.0
# 198    0.0
# 199    0.0
# 200    0.0
# 201    0.0
# 202    0.0
# 461    0.0
# 464    0.0
# Name: ASP_USD, dtype: float64

# %%
df['ASP_USD'].nlargest(10)
# Out:
# 2200     67.00000
# 2179     57.68578
# 16114     1.70000
# 16117     1.60000
# 16118     1.60000
# 16119     1.60000
# 16120     1.60000
# 16121     1.60000
# 16122     1.60000
# 7521      1.00000
# Name: ASP_USD, dtype: float64

# %%
menores_uno_usd = df.loc[df['ASP_USD'] < 1]['ASP_USD'].count()
menores_uno_usd
# Out:
# 13727

# %%
#Mas del 99,9% de los datos estan entre 0 y 1
menores_uno_usd *100 / no_nulos_usd
# Out:
# 99.91993012083273

# %%
menores_uno = (df['ASP_USD'] <= 1)
menores_uno.value_counts()
# Out:
# True     13729
# False     3218
# Name: ASP_USD, dtype: int64

# %%
mayores_uno = (df['ASP_USD'] > 1)
mayores_uno.value_counts()
# Out:
# False    16938
# True         9
# Name: ASP_USD, dtype: int64

# %%
nulos = df['ASP_USD'].isna()
nulos.value_counts()
# Out:
# False    13738
# True      3209
# Name: ASP_USD, dtype: int64

# %%
g = pd.DataFrame()
g['Menores a uno'] = menores_uno
g['Mayores a uno'] = mayores_uno
g['Nulos'] = nulos
plt.figure(figsize=(11, 7))
ax = sns.barplot(data = g)

for p in ax.patches:
    txt = str((p.get_height()*100).round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    ax.text(txt_x,txt_y,txt)

plt.title('Distribución de la variable ASP_USD', size=14, y=1.02, fontweight ='bold')

#plt.savefig('Visualizacion5.png', bbox_inches='tight')

# %%
g = df[['ASP_USD']].dropna().copy()

g['Menores a uno'] = (g['ASP_USD'] <= 1)
g['Mayores a uno'] = (g['ASP_USD'] > 1)
g = g.drop(columns='ASP_USD')
plt.figure(figsize=(11, 7))
ax = sns.barplot(data = g)

for p in ax.patches:
    txt = str((p.get_height()*100).round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    ax.text(txt_x,txt_y,txt)

plt.title('Distribución de la variable ASP_USD (sin valores nulos)', size=14, y=1.02, fontweight ='bold')

#plt.savefig('Visualizacion6.png', bbox_inches='tight')

# %%
g
# Out:
#        Menores a uno  Mayores a uno
# 0               True          False
# 1               True          False
# 2               True          False
# 3               True          False
# 4               True          False
# ...              ...            ...
# 16942           True          False
# 16943           True          False
# 16944           True          False
# 16945           True          False
# 16946           True          False
#
# [13738 rows x 2 columns]

# %%
plt.style.use('ggplot')
values = ['Closed Won', 'Closed Lost']

g = df.loc[:,['ASP_USD','Stage']]
g = g.sort_values('ASP_USD', ascending=False).iloc[no_nulos_usd - menores_uno_usd:]
g = g.loc[g['Stage'].isin(values)]

plt.figure(figsize=(12,7.5))

g['Stage'] = g['Stage'].map({'Closed Lost':'Fracaso', 'Closed Won':'Exito'})
g = g.rename(columns={'Stage':'Resultado de la oportunidad'\
                  ,'ASP_USD':'Precio de venta promedio (USD)'})

sns.kdeplot(data=g, x='Precio de venta promedio (USD)'\
            , hue='Resultado de la oportunidad', fill=True, palette=palette_dic)

plt.title('Distribución del precio de venta promedio (USD) según el resultado de la oportunidad', size=14, y=1.02, fontweight ='bold')

#plt.savefig('Visualizacion7.png', bbox_inches='tight')

# %% [markdown]
# Analisis para la variable 'ASP'

# %%
nulos = df['ASP'].isna().sum()
nulos
# Out:
# 3209

# %%
no_nulos = df['ASP'].count()
no_nulos
# Out:
# 13738

# %%
total = len(df['ASP'])
total
# Out:
# 16947

# %%
#No contiene datos menores a 0
df['ASP'].nsmallest(10)
# Out:
# 110    0.0
# 196    0.0
# 197    0.0
# 198    0.0
# 199    0.0
# 200    0.0
# 201    0.0
# 202    0.0
# 461    0.0
# 464    0.0
# Name: ASP, dtype: float64

# %%
menores_uno = df.loc[df['ASP'] < 1]['ASP'].count()
menores_uno
# Out:
# 12169

# %%
#Mas del 88% de los datos estan entre 0 y 1
menores_uno *100 / no_nulos
# Out:
# 88.57912359877712

# %%
g = df[['ASP_Currency','ASP','ASP_USD','Stage']]
g.groupby('ASP_Currency').describe().transpose()
# Out:
# ASP_Currency          AUD          EUR       GBP          JPY          USD
# ASP     count  556.000000  4501.000000  5.000000  1786.000000  6890.000000
#         mean     0.541883     0.390180  0.361000    51.150056     0.423705
#         std      0.066138     0.758547  0.002236    22.190085     0.809836
#         min      0.330000     0.000000  0.360000     0.000000     0.000000
#         25%      0.500000     0.335000  0.360000    46.000000     0.368750
#         50%      0.535000     0.370000  0.360000    55.000000     0.400000
#         75%      0.540000     0.410000  0.360000    67.000000     0.460000
#         max      0.780000    51.000000  0.365000    80.000000    67.000000
# ASP_USD count  556.000000  4501.000000  5.000000  1786.000000  6890.000000
#         mean     0.383443     0.441331  0.475818     0.459740     0.423705
#         std      0.046800     0.857988  0.002947     0.199507     0.809836
# ...

# %%
#GPB tiene solo 5 valores los elimino
#Los elimino por cuestiones graficas pero en el analisis tener en cuenta que las 5 son Closed Lost
g = g.drop(index=g.loc[g['ASP_Currency'] == 'GBP'].index)
g
# Out:
#       ASP_Currency     ASP  ASP_USD        Stage
# 0              EUR  0.5200  0.58817  Closed Lost
# 1              EUR  0.5300  0.59948   Closed Won
# 2              USD  0.4800  0.48000   Closed Won
# 3              USD  0.5300  0.53000  Closed Lost
# 4              USD  0.5300  0.53000  Closed Lost
# ...            ...     ...      ...          ...
# 16942          EUR  0.5200  0.58817   Closed Won
# 16943          EUR  0.5200  0.58817   Closed Won
# 16944          EUR  0.5200  0.58817   Closed Won
# 16945          USD  0.6375  0.63750  Closed Lost
# 16946          USD  0.6400  0.64000  Closed Lost
#
# [16942 rows x 4 columns]

# %%
g.loc[g['ASP_Currency'] == 'EUR']['ASP_USD'].nlargest(10)
# Out:
# 2179    57.68578
# 4980     0.70128
# 3315     0.67300
# 182      0.66169
# 183      0.66169
# 438      0.66169
# 1873     0.66169
# 1878     0.66169
# 2219     0.66169
# 3190     0.66169
# Name: ASP_USD, dtype: float64

# %%
#EUR tiene un solo valor > 1. Lo elimino
g = g.drop(2179)
g
# Out:
#       ASP_Currency     ASP  ASP_USD        Stage
# 0              EUR  0.5200  0.58817  Closed Lost
# 1              EUR  0.5300  0.59948   Closed Won
# 2              USD  0.4800  0.48000   Closed Won
# 3              USD  0.5300  0.53000  Closed Lost
# 4              USD  0.5300  0.53000  Closed Lost
# ...            ...     ...      ...          ...
# 16942          EUR  0.5200  0.58817   Closed Won
# 16943          EUR  0.5200  0.58817   Closed Won
# 16944          EUR  0.5200  0.58817   Closed Won
# 16945          USD  0.6375  0.63750  Closed Lost
# 16946          USD  0.6400  0.64000  Closed Lost
#
# [16941 rows x 4 columns]

# %%
g = g.sort_values('ASP_USD', ascending=False).iloc[no_nulos_usd - menores_uno_usd:]
values = ['Closed Won', 'Closed Lost']
g = g.loc[g['Stage'].isin(values)]
g['Stage'] = g['Stage'].map({'Closed Lost':'Fracaso', 'Closed Won':'Exito'})

sns.catplot(x='ASP_Currency', y='ASP_USD', hue='Stage', palette=palette_dic \
            , kind="violin", split=True, data=g, height=7, aspect=1.2, legend=False)
plt.title('Distribución de las monedas segun su precio promedio de venta en USD', size=14, y=1.02,\
             fontweight ='bold')
plt.xlabel('Moneda')
plt.ylabel('Precio promedio de venta (USD)')
plt.legend(title='Resultado de la oportunidad')

#plt.savefig('Visualizacion8.png', bbox_inches='tight')

# %%
g = df.loc[:, 'Last_Modified_Date']
g
# Out:
# 0       2016-06-13
# 1       2016-01-15
# 2       2016-09-29
# 3       2018-03-27
# 4       2018-03-27
#            ...
# 16942   2016-01-19
# 16943   2016-01-19
# 16944   2016-01-19
# 16945   2016-01-22
# 16946   2016-09-28
# Name: Last_Modified_Date, Length: 16947, dtype: datetime64[ns]

# %%
import matplotlib.dates as mdates
sns.displot(g, height=7, aspect=1.5)

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=90)
plt.title('Distribución de la cantidad de oportunidades segun su ultima fecha de modificacion\
 (mensual)', size=14, y=1.02, fontweight ='bold')

plt.ylabel('Cantidad de oportunidades')
plt.xlabel('Fecha de ultima modificacion')

#plt.savefig('Visualizacion9.png', bbox_inches='tight')

# %% [markdown]
# Como se aprecia en el grafico la mayoria de los datos estan entre noviembre de 2016
# y enero del 2019 aproximadamente

# %%
g = df.loc[:,['Last_Modified_Date', 'Product_Family', 'Stage']]
g
# Out:
#       Last_Modified_Date      Product_Family        Stage
# 0             2016-06-13   Product_Family_77  Closed Lost
# 1             2016-01-15   Product_Family_77   Closed Won
# 2             2016-09-29   Product_Family_81   Closed Won
# 3             2018-03-27  Product_Family_209  Closed Lost
# 4             2018-03-27  Product_Family_209  Closed Lost
# ...                  ...                 ...          ...
# 16942         2016-01-19   Product_Family_85   Closed Won
# 16943         2016-01-19   Product_Family_85   Closed Won
# 16944         2016-01-19   Product_Family_85   Closed Won
# 16945         2016-01-22  Product_Family_158  Closed Lost
# 16946         2016-09-28  Product_Family_164  Closed Lost
#
# [16947 rows x 3 columns]

# %%
#Me quedo con las 10 familias de productos con mas datos
familias10 = g['Product_Family'].value_counts().nlargest(10).index.tolist()
familias10
# Out:
# ['Product_Family_77',
#  'Product_Family_133',
#  'Product_Family_132',
#  'Product_Family_212',
#  'Product_Family_100',
#  'Product_Family_85',
#  'Product_Family_115',
#  'Product_Family_226',
#  'Product_Family_109',
#  'Product_Family_208']

# %%
g = g.loc[g['Product_Family'].isin(familias10)]
values = ['Closed Won', 'Closed Lost']
g = g.loc[g['Stage'].isin(values)]
g = g.loc[(g['Last_Modified_Date'] > '2016-11-01') & (g['Last_Modified_Date'] < '2019-01-31')]
g
# Out:
#       Last_Modified_Date      Product_Family        Stage
# 66            2017-01-12   Product_Family_77   Closed Won
# 67            2017-01-12   Product_Family_77   Closed Won
# 68            2017-01-12   Product_Family_77  Closed Lost
# 69            2017-05-13  Product_Family_115  Closed Lost
# 70            2017-01-12   Product_Family_77   Closed Won
# ...                  ...                 ...          ...
# 16858         2016-12-12   Product_Family_77  Closed Lost
# 16860         2017-06-27   Product_Family_85   Closed Won
# 16882         2017-09-08  Product_Family_226  Closed Lost
# 16884         2017-09-08   Product_Family_77  Closed Lost
# 16928         2016-11-07   Product_Family_85  Closed Lost
#
# [6924 rows x 3 columns]

# %%
#Me quedo con las 10 familias de productos con mas datos
familias10 = g['Product_Family'].value_counts().nlargest(10).index.tolist()
familias10
# Out:
# ['Product_Family_133',
#  'Product_Family_77',
#  'Product_Family_132',
#  'Product_Family_212',
#  'Product_Family_100',
#  'Product_Family_85',
#  'Product_Family_115',
#  'Product_Family_109',
#  'Product_Family_208',
#  'Product_Family_226']

# %%
g = g.groupby([g['Last_Modified_Date'].dt.to_period('M'),'Product_Family', 'Stage'])\
        .count().unstack()
g
# Out:
#                                       Last_Modified_Date
# Stage                                        Closed Lost Closed Won
# Last_Modified_Date Product_Family
# 2016-11            Product_Family_85                 1.0        NaN
# 2016-12            Product_Family_100                NaN        3.0
#                    Product_Family_115               13.0       73.0
#                    Product_Family_226              104.0       95.0
#                    Product_Family_77               320.0      372.0
# ...                                                  ...        ...
# 2018-12            Product_Family_109               10.0        8.0
#                    Product_Family_132               36.0       28.0
#                    Product_Family_133               11.0       34.0
#                    Product_Family_208               10.0       23.0
#                    Product_Family_212               19.0        8.0
#
# [176 rows x 2 columns]

# %%
g = g.reset_index()
g.columns = ['Last_Modified_Date', 'Product_Family', 'Fracaso',\
   'Exito']
g
# Out:
#     Last_Modified_Date      Product_Family  Fracaso  Exito
# 0              2016-11   Product_Family_85      1.0    NaN
# 1              2016-12  Product_Family_100      NaN    3.0
# 2              2016-12  Product_Family_115     13.0   73.0
# 3              2016-12  Product_Family_226    104.0   95.0
# 4              2016-12   Product_Family_77    320.0  372.0
# ..                 ...                 ...      ...    ...
# 171            2018-12  Product_Family_109     10.0    8.0
# 172            2018-12  Product_Family_132     36.0   28.0
# 173            2018-12  Product_Family_133     11.0   34.0
# 174            2018-12  Product_Family_208     10.0   23.0
# 175            2018-12  Product_Family_212     19.0    8.0
#
# [176 rows x 4 columns]

# %%
start_end = pd.DataFrame([[0, 0], [0, 0]], columns=['Fracaso', 'Exito'],\
                         index=[pd.Period('2016-11', 'M'), pd.Period('2019-01', 'M')])

g.loc[g['Product_Family'] == familias10[4]].set_index('Last_Modified_Date')\
      [['Fracaso','Exito']].append(start_end)
# Out:
#          Fracaso  Exito
# 2016-12      NaN    3.0
# 2017-01      1.0    NaN
# 2017-02      2.0    1.0
# 2017-03      2.0    NaN
# 2017-04      2.0    NaN
# 2017-06      2.0    NaN
# 2017-07      2.0    NaN
# 2017-08      2.0    NaN
# 2017-09      2.0    2.0
# 2017-10      3.0    NaN
# 2017-11      NaN    2.0
# 2017-12      3.0    NaN
# 2018-01      NaN    1.0
# 2018-02    150.0  171.0
# 2018-03     19.0   14.0
# 2018-04     14.0    8.0
# 2018-05     16.0    5.0
# 2018-06     11.0   14.0
# 2018-07      8.0   16.0
# 2018-08     17.0    6.0
# 2018-09     16.0   33.0
# 2018-10      6.0   16.0
# 2018-11     12.0   12.0
# 2018-12     12.0   13.0
# 2016-11      0.0    0.0
# 2019-01      0.0    0.0

# %%
import datetime as dt

rojo = sns.color_palette('Paired', 10)[5]
verde = sns.color_palette('Paired', 10)[3]

columnas = 2
filas = 5
fig, axes = plt.subplots(nrows=filas, ncols=columnas, figsize=(20,50), sharex=True)
fig.suptitle('Cantidad de oportunidades de las 10 familias de producto mas requeridas por mes'\
          , size=20,y=.9, fontweight ='bold')
        
for i in range(filas):
    for j in range(columnas):
        indice = 2*i + j
        h = g.loc[g['Product_Family'] == familias10[indice]].set_index('Last_Modified_Date')\
        [['Fracaso','Exito']].copy()
        if i == filas-1:
            h = h.append(start_end)
        h.plot(kind='bar', ax=axes[i,j],color=[rojo,verde])

for i, ax in enumerate(axes.ravel()):
    ax.set_title("{}".format(familias10[i]))      

for ax in axes.flatten():
    ax.xaxis.set_tick_params(labelbottom=True)
    ax.tick_params(axis='x', rotation=90)
    
plt.setp(axes[-1, :], xlabel='Fecha de ultima modificacion')
plt.setp(axes[:, 0], ylabel='Cantidad de oportunidades')

#plt.savefig('Visualizacion10.png', bbox_inches='tight')
